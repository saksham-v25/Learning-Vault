# %% [markdown]
# ### What is Pandas
#
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,
# built on top of the Python programming language.
#
# https://pandas.pydata.org/about/index.html

# %% [markdown]
# ### Pandas Series
#
# A Pandas Series is like a column in a table. It is a 1-D array holding data of any type.

# %% [markdown]
# ### Pandas Series
#
# A Pandas Series is like a column in a table. It is a 1-D array holding data of any type.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Series from lists

# %%
#string
country=['India','Pakistan','USA','Nepal','Srilanka']
pd.Series(country)
# Out:
# 0       India
# 1    Pakistan
# 2         USA
# 3       Nepal
# 4    Srilanka
# dtype: object

# %%
#integer
run=[12,45,47,34,60]
pd.Series(run)
# Out:
# 0    12
# 1    45
# 2    47
# 3    34
# 4    60
# dtype: int64

# %%
#custom index
marks=[67,57,89,100]
subject=['Maths','English','Science','Hindi']

# %%
pd.Series(marks)
# Out:
# 0     67
# 1     57
# 2     89
# 3    100
# dtype: int64

# %%
pd.Series(marks,index=subject)
# Out:
# Maths       67
# English     57
# Science     89
# Hindi      100
# dtype: int64

# %%
#setting a name

# %%
pd.Series(marks,index=subject,name='Saksham ke marks')
# Out:
# Maths       67
# English     57
# Science     89
# Hindi      100
# Name: Saksham ke marks, dtype: int64

# %%
marks=pd.Series(marks,index=subject,name='Saksham ke marks')
marks
# Out:
# Maths       67
# English     57
# Science     89
# Hindi      100
# Name: Saksham ke marks, dtype: int64

# %% [markdown]
# ### Series from dict

# %%
marks={
    'Maths':67,
    'English':57,
    'Science':89,
    'Hindi':100
}

marks_series = pd.Series(marks,name='Saksham ke marks')
marks_series
# Out:
# Maths       67
# English     57
# Science     89
# Hindi      100
# Name: Saksham ke marks, dtype: int64

# %% [markdown]
# ### Series from dict

# %%
#size
marks_series.size
# Out:
# 4

# %%
#dtype
marks_series.dtype
# Out:
# dtype('int64')

# %%
#name
marks_series.name
# Out:
# 'Saksham ke marks'

# %%
# is_unique
marks_series.is_unique
# Out:
# True

# %%
pd.Series([1,1,2,3,4]).is_unique
# Out:
# False

# %%
#index
marks_series.index
# Out:
# Index(['Maths', 'English', 'Science', 'Hindi'], dtype='object')

# %%
runs_ser=[12,45,47,34,60]
runs_ser=pd.Series(runs_ser)
runs_ser.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
#values
marks_series.values
# Out:
# array([ 67,  57,  89, 100])

# %%
type(marks_series.values)
# Out:
# numpy.ndarray

# %% [markdown]
# ### Series using read_csv

# %%
#csv stand for comma seperated values

# %%
#with one col
subs=pd.read_csv('/content/subs.csv',).squeeze('columns')
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
type(subs)
# Out:
# pandas.core.series.Series

# %%
#with 2 col
vk=pd.read_csv('/content/kohli_ipl.csv',index_col='match_no').squeeze('columns')
print(vk)
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
type(vk)
# Out:
# pandas.core.series.Series

# %%
print(type(vk))
# Out:
# <class 'pandas.core.series.Series'>

# %%
movies=pd.read_csv("/content/bollywood.csv",index_col='movie').squeeze('columns')

# %%
print(movies)
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# ### Series Maths Methods

# %%
 #head and tail
 #head bydefault top ke 5 rows nikaal ke dega
 subs.head()
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# Name: Subscribers gained, dtype: int64

# %%
subs.head(3)
# Out:
# 0    48
# 1    57
# 2    40
# Name: Subscribers gained, dtype: int64

# %%
#tail last ke 5 row bydeafault nikaal ke dega
subs.tail()
# Out:
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, dtype: int64

# %%
subs.tail(3)
# Out:
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, dtype: int64

# %%
#sample = koi random data nikaal ke dega
subs.sample()
# Out:
# 33    49
# Name: Subscribers gained, dtype: int64

# %%
# 5 means koi 5 random data nikaal ke dega
movies.sample(5)
# Out:
# movie
# Gollu Aur Pappu            Dimple Kapadia
# Lakshya (film)             Hrithik Roshan
# Raincoat (film)                Ajay Devgn
# Chura Liyaa Hai Tumne          Zayed Khan
# Bol Bachchan             Amitabh Bachchan
# Name: lead, dtype: object

# %%
vk.sample()
# Out:
# match_no
# 212    20
# Name: runs, dtype: int64

# %%
# value_counts -> movies
movies.value_counts()
# Out:
# lead
# Akshay Kumar          48
# Amitabh Bachchan      45
# Ajay Devgn            38
# Salman Khan           31
# Sanjay Dutt           26
#                       ..
# Talha Arshad Reshi     1
# Garima Agarwal         1
# Rasika Agashe          1
# Zaheer Iqbal           1
# Deepika Amin           1
# Name: count, Length: 566, dtype: int64

# %%
movies.value_counts()['Akshay Kumar']
# Out:
# np.int64(48)

# %%
# sort_values -> inplace
vk.sort_values(ascending=False)
# Out:
# match_no
# 128    113
# 126    109
# 123    108
# 120    100
# 164    100
#       ...
# 93       0
# 130      0
# 206      0
# 207      0
# 211      0
# Name: runs, Length: 215, dtype: int64

# %%
vk.sort_values(ascending=False).head(1).values[0]
# Out:
# np.int64(113)

# %%
vk.sort_values(ascending=False)
# Out:
# match_no
# 128    113
# 126    109
# 123    108
# 120    100
# 164    100
#       ...
# 93       0
# 130      0
# 206      0
# 207      0
# 211      0
# Name: runs, Length: 215, dtype: int64

# %%
# sort_index -> inplace -> movies
vk=vk.copy()

vk.sort_values(inplace=True)

# %%
vk
# Out:
# match_no
# 8        0
# 87       0
# 93       0
# 91       0
# 206      0
#       ...
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, Length: 215, dtype: int64

# %%
# sort_index -> inplace -> movies
movies.sort_index(inplace=True)
movies
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# ### Series Maths Methods

# %%
#count
#size missing values ko count nahi karta hai
#count missing values ko count karta hai
vk.count()
# Out:
# np.int64(215)

# %%
print(vk.count())
# Out:
# 215

# %%
# sum -> product
subs.sum()
# Out:
# np.int64(49510)

# %%
# sum -> product
subs.sum()
subs.product()
#zero isliye dikha rha hai kyu kisi din ka value zero hai
# Out:
# np.int64(0)

# %%
# mean -> median -> mode -> std -> var
subs.mean()
# Out:
# np.float64(135.64383561643837)

# %%
vk.median()
# Out:
# 24.0

# %%
movies.mode()
# Out:
# 0    Akshay Kumar
# Name: lead, dtype: object

# %%
subs.std()
# Out:
# 62.67502303725269

# %%
vk.var()
# Out:
# 688.0024777222342

# %%
# min/max
subs.min()
# Out:
# 33

# %%
subs.max()
# Out:
# 396

# %%
#describe
vk.describe()
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %% [markdown]
# ### Series Indexing

# %%
#integer indexing
x = pd.Series([12,13,14,35,46,57,58,79,9])
x[0]
# Out:
# np.int64(12)

# %%
x[7]
# Out:
# np.int64(79)

# %%
#negative indexing
x[0]
# Out:
# np.int64(12)

# %%
print(movies[0])
# Out:
# Rajniesh Duggall
# /tmp/ipykernel_1045/846308596.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(movies[0])

# %%
movies["Zor Lagaa Ke...Haiya!"]
# Out:
# 'Meghan Jadhav'

# %%
movies[-1]
# Out:
# /tmp/ipykernel_1045/2731571422.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   movies[-1]
# 'Meghan Jadhav'

# %%
# slicing
vk[5:16]
# Out:
# match_no
# 207    0
# 135    0
# 130    0
# 211    0
# 106    1
# 204    1
# 113    1
# 77     1
# 1      1
# 5      1
# 75     1
# Name: runs, dtype: int64

# %%
# negative slicing
vk[-5:]
# Out:
# match_no
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, dtype: int64

# %%
movies[-5:]
# Out:
# movie
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, dtype: object

# %%
movies[::2]
# Out:
# movie
# 1920 (film)                 Rajniesh Duggall
# 1920: The Evil Returns           Vicky Ahuja
# 2 States (2014 film)            Arjun Kapoor
# 3 A.M. (2014 film)             Salil Acharya
# 3 Idiots                          Aamir Khan
#                                   ...
# Zero (2018 film)              Shah Rukh Khan
# Zila Ghaziabad                  Vivek Oberoi
# Zindaggi Rocks                  Sushmita Sen
# Zindagi Na Milegi Dobara      Hrithik Roshan
# Zokkomon                     Darsheel Safary
# Name: lead, Length: 750, dtype: object

# %%
#fancy indexing
vk[[1,3,4,5]]
# Out:
# match_no
# 1     1
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
# indexing with labels -> fancy indexing
movies['2 States (2014 film)']
# Out:
# 'Arjun Kapoor'

# %% [markdown]
# ### Editing Series

# %%
# using indexing
marks_series
# Out:
# Maths       67
# English     57
# Science     89
# Hindi      100
# Name: Saksham ke marks, dtype: int64

# %%
#englisha ka markd change kar sakte hai
marks_series[1]=100
# Out:
# /tmp/ipykernel_1045/3701823500.py:2: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks_series[1]=100

# %%
marks_series
# Out:
# Maths       67
# English    100
# Science     89
# Hindi      100
# Name: Saksham ke marks, dtype: int64

# %%
# what if an index does not exist
marks_series["sst"]=90

# %%
marks_series
# Out:
# Maths       67
# English    100
# Science     89
# Hindi      100
# sst         90
# Name: Saksham ke marks, dtype: int64

# %%
#slicing
runs_ser[2:4]=[100,100]
runs_ser
# Out:
# 0     12
# 1     45
# 2    100
# 3    100
# 4     60
# dtype: int64

# %%
# fancy indexing
runs_ser[[0,3,4]]=[0,0,0]
runs_ser
# Out:
# 0      0
# 1     45
# 2    100
# 3      0
# 4      0
# dtype: int64

# %%
movies
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %%
movies["2 States (2014 film)"]
# Out:
# 'Arjun Kapoor'

# %%
# using index label
movies["2 States (2014 film)"]="Alia Bhatt"

# %%
movies["2 States (2014 film)"]
# Out:
# 'Alia Bhatt'

# %% [markdown]
# ### Series with Python Functionalities

# %%
# len/type/dir/sorted/max/min
print(len(subs))
print(type(subs))
print(dir(subs))
print(sorted(subs))
print(min(subs))
print(max(subs))
# Out:
# 365
# <class 'pandas.core.series.Series'>
# ...

# %%
# type conversion
list(marks_series)
# Out:
# [67, 100, 89, 100, 90]

# %%
dict(marks_series)
# Out:
# {'Maths': np.int64(67),
#  'English': np.int64(100),
#  'Science': np.int64(89),
#  'Hindi': np.int64(100),
#  'sst': np.int64(90)}

# %%
movies
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)                Alia Bhatt
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %%
#membership operator
"2 States (2014 film)" in movies
# Out:
# True

# %%
"Alia Bhatt" in movies
# Out:
# False

# %%
"Alia Bhatt" in movies.values
# Out:
# True

# %%
# looping
for i in movies.index:
  print(i)
# Out:
# 1920 (film)
# 1920: London
# 1920: The Evil Returns
# 1971 (2007 film)
# 2 States (2014 film)
# 22 Yards
# 3 A.M. (2014 film)
# 3 Deewarein
# 3 Idiots
# 3 Storeys
# 31st October (film)
# 36 China Town
# 3G (film)
# 404 (film)
# 5 Weddings
# 68 Pages
# 7 Hours to Go
# 7 Khoon Maaf
# 7½ Phere
# 88 Antop Hill
# 99 (2009 film)
# 99.9 FM (film)
# ?: A Question Mark
# A Decent Arrangement
# A Flat (film)
# A Flying Jatt
# A Gentleman
# ABCD 2
# Aa Dekhen Zara
# Aa Gaya Hero
# Aabra Ka Daabra
# Aag (2007 film)
# Aagey Se Right
# Aaj Ka Andha Kanoon
# Aaja Nachle
# Aakhari Decision
# Aakrosh (2010 film)
# Aalaap (film)
# Aan: Men at Work
# Aanch
# Aankhen (2002 film)
# Aap Kaa Surroor
# Aap Ki Khatir (2006 film)
# Aapko Pehle Bhi Kahin Dekha Hai
# Aarakshan
# Aashayein
# Aashiq Banaya Aapne
# Aashiqui 2
# Aashiqui.in
# Aasma: The Sky Is the Limit
# Aazaan
# Ab Tak Chhappan 2
# Ab Tumhare Hawale Watan Saathiyo
# Accident on Hill Road
# Acid Factory
# Action Jackson (2014 film)
# ...

# %%
# Arithmetic Operators(Broadcasting)
100 - marks_series
# Out:
# Maths      33
# English     0
# Science    11
# Hindi       0
# sst        10
# Name: Saksham ke marks, dtype: int64

# %%
#Relational operators
vk  >= 50
# Out:
# match_no
# 8      False
# 87     False
# 93     False
# 91     False
# 206    False
#        ...
# 164     True
# 120     True
# 123     True
# 126     True
# 128     True
# Name: runs, Length: 215, dtype: bool

# %% [markdown]
# ### Boolean Indexing on Series

# %%
# Find no of 50's and 100's scored by kohli
vk[vk >= 50].size
# Out:
# 50

# %%
# find number of ducks
vk[vk ==0].size
# Out:
# 9

# %%
# Count number of day when I had more than 200 subs a day
subs[subs > 200].size
# Out:
# 59

# %%
# find actors who have done more than 20 movies
num_movies=movies.value_counts()

# %%
num_movies[num_movies > 20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %% [markdown]
# ### Plotting Graphs on Series

# %%
subs.plot()
# Out:
# <Axes: >

# %%
movies.value_counts().head(20).plot(kind="bar")
# Out:
# <Axes: xlabel='lead'>

# %%
movies.value_counts().head(20).plot(kind="pie")
# Out:
# <Axes: ylabel='count'>
